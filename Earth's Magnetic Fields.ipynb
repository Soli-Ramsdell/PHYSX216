# %%
#Physics 218
#Soli Ramsdell
#March 2021

import physplot as phys
import numpy as np

thetaDeg = np.array([-50,-40,-30,-20,-10,10,20,30,40,50])
thetaRad = np.deg2rad(thetaDeg)
tanTheta = np.tan(thetaRad)
I100 = np.array([37.0,25.9,17.44,10.22,5.27,-5.28,-10.66,-17.4,-27.1,-39.0])
#I200 = np.array([17.8,13.12,8.86,4.97,2.04,-2.70,-5.95,-9.21,-13.66,-21.0])

errI = np.ones(10)*0.2

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(tanTheta,I100,errI,'B_E Deflection: 100 Coils','theta($deg$)','I($mA$)','mA/deg')
# Out:
# Slope =  -31.400958614610825   mA/deg
# Error in slope =  0.0873493429214314   mA/deg
# Goodness of fit =  133.19483257351007

# %%
import physplot as phys
import numpy as np

thetaDeg = np.array([-50,-40,-30,-20,-10,10,20,30,40,50])
thetaRad = np.deg2rad(thetaDeg)
tanTheta = np.tan(thetaRad)
#I100 = np.array([37.0,25.9,17.44,10.22,5.27,-5.28,-10.66,-17.4,-27.1,-39.0])
I200 = np.array([17.8,13.12,8.86,4.97,2.04,-2.70,-5.95,-9.21,-13.66,-21.0])

errI = np.ones(10)*0.2

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(tanTheta,I200,errI,'B_E Deflection: 200 Coils','theta($deg$)','I($mA$)','mA/deg')
# Out:
# Slope =  -16.014068366030717   mA/deg
# Error in slope =  0.0873493429214314   mA/deg
# Goodness of fit =  92.93110189064576
