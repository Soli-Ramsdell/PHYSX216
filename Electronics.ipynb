# %%
import numpy as np
import physplot as phys

V = np.array([1.55,3.11,4.72,5.36])
I = np.array([.476,.667,.857,.940])

errI = np.ones(4)*0.002

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(V,I,errI,'Lamp Bulb','V($V$)','I($A$)','kOhms')
# Out:
# Slope =  0.1211209601058672   kOhms
# Error in slope =  0.0006755176395643442   kOhms
# Goodness of fit =  4.666361499937205
